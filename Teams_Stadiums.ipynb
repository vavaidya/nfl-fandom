# %%
import pandas as pd 
import xml.etree.ElementTree as et 

xtree = et.parse("Stadiums.xml")
xroot = xtree.getroot() 

df_cols = ["stadiumID","stadium_name", "state", "country", "latitude", "longitude", "capacity"]
rows = []


for node in xroot:
    s_ID = node.find("StadiumID").text if node is not None else None
    s_name = node.find("Name").text if node is not None else None
    s_state = node.find("State").text if node is not None else None
    s_country = node.find("Country").text if node is not None else None
    s_cap = node.find("Capacity").text if node is not None else None
    s_lat = node.find("GeoLat").text if node is not None else None
    s_lon = node.find("GeoLong").text if node is not None else None

    rows.append({"stadiumID":s_ID,"stadium_name": s_name, 
                 "state": s_state, "country":s_country,
                 "latitude":s_lat, "longitude":s_lon, "capacity": s_cap})

out_df = pd.DataFrame(rows, columns = df_cols)

# %%
out_df.head()
# Out:
#   stadiumID        stadium_name state country   latitude   longitude capacity
# 0         1       New Era Field    NY     USA  42.773758  -78.786837    73079
# 1         2   Hard Rock Stadium    FL     USA  25.957740  -80.238781    76100
# 2         3     MetLife Stadium    NJ     USA  40.813611  -74.074444    82500
# 3         4    Gillette Stadium    MA     USA  42.090866  -71.264244    68756
# 4         5  Paul Brown Stadium    OH     USA  39.095309  -84.516003    65535

# %%
import pandas as pd 
import xml.etree.ElementTree as et 

xtree = et.parse("Teams.xml")
xroot = xtree.getroot() 

df_cols = ["key","ID","Team","Name","conference","division","full_name","stadiumID"]
rows = []


for node in xroot.findall('Team'):
    
    t_key = node.find("Key").text if node is not None else None
    t_TeamID = node.find("TeamID").text if node is not None else None
    t_city = node.find("City").text if node is not None else None
    t_name = node.find("Name").text if node is not None else None
    t_conf = node.find("Conference").text if node is not None else None
    t_div = node.find("Division").text if node is not None else None
    t_full = node.find("FullName").text if node is not None else None
    t_s_ID = node.find("StadiumID").text if node is not None else None
    rows.append({"key": t_key, "ID": t_TeamID, 
             "Team": t_city, "Name":t_name,
             "conference":t_conf, "division":t_div, "full_name": t_full, "stadiumID":t_s_ID})
team_df = pd.DataFrame(rows, columns = df_cols)

# %%
team_df.head()
# Out:
#    key ID       Team       Name conference division          full_name  \
# 0  ARI  1    Arizona  Cardinals        NFC     West  Arizona Cardinals
# 1  ATL  2    Atlanta    Falcons        NFC    South    Atlanta Falcons
# 2  BAL  3  Baltimore     Ravens        AFC    North   Baltimore Ravens
# 3  BUF  4    Buffalo      Bills        AFC     East      Buffalo Bills
# 4  CAR  5   Carolina   Panthers        NFC    South  Carolina Panthers
#
#   stadiumID
# 0        29
# 1        45
# 2         7
# 3         1
# 4        26

# %%
teams_stadium = pd.merge(team_df,
                 out_df,
                 on='stadiumID')
teams_stadium.head()
# Out:
#    key ID       Team       Name conference division          full_name  \
# 0  ARI  1    Arizona  Cardinals        NFC     West  Arizona Cardinals
# 1  ATL  2    Atlanta    Falcons        NFC    South    Atlanta Falcons
# 2  BAL  3  Baltimore     Ravens        AFC    North   Baltimore Ravens
# 3  BUF  4    Buffalo      Bills        AFC     East      Buffalo Bills
# 4  CAR  5   Carolina   Panthers        NFC    South  Carolina Panthers
#
#   stadiumID             stadium_name state country   latitude    longitude  \
# 0        29     U of Phoenix Stadium    AZ     USA  33.527558  -112.263036
# 1        45    Mercedes-Benz Stadium    GA     USA  33.755000   -84.401000
# 2         7         M&T Bank Stadium    MD     USA  39.277985   -76.622788
# 3         1            New Era Field    NY     USA  42.773758   -78.786837
# 4        26  Bank of America Stadium    NC     USA  35.225808   -80.852861
#
#   capacity
# 0    63400
# 1    71000
# 2    71008
# 3    73079
# 4    73778

# %%
attendance = pd.read_csv("Attendance.csv")

attendance['Average attendance'] = attendance['Average attendance'].str.replace(',', '')
attendance.head()
# Out:
#                 Team      Metro                       Stadium  Home games  \
# 0     Dallas Cowboys     Dallas                  AT&T Stadium           8
# 1      New York Jets   New York               MetLife Stadium           8
# 2  Green Bay Packers  Green Bay                 Lambeau Field           8
# 3    New York Giants   New York               MetLife Stadium           8
# 4     Denver Broncos     Denver  Broncos Stadium at Mile High           8
#
#   Average attendance Total attendance Capacity percentage
# 0              91620          732,958             114.50%
# 1              77982          623,856             100.00%
# 2              77835          622,677              95.60%
# 3              76941          615,525              93.30%
# 4              76446          611,571             100.40%

# %%
teams_attendance = pd.merge(teams_stadium,
                 attendance[['Team','Average attendance', 'Metro']],
                 left_on='full_name', right_on='Team')
teams_attendance=teams_attendance.drop('Team_y', axis =1 )
teams_attendance.head()
# Out:
#    key ID     Team_x       Name conference division          full_name  \
# 0  ARI  1    Arizona  Cardinals        NFC     West  Arizona Cardinals
# 1  ATL  2    Atlanta    Falcons        NFC    South    Atlanta Falcons
# 2  BAL  3  Baltimore     Ravens        AFC    North   Baltimore Ravens
# 3  BUF  4    Buffalo      Bills        AFC     East      Buffalo Bills
# 4  CAR  5   Carolina   Panthers        NFC    South  Carolina Panthers
#
#   stadiumID             stadium_name state country   latitude    longitude  \
# 0        29     U of Phoenix Stadium    AZ     USA  33.527558  -112.263036
# 1        45    Mercedes-Benz Stadium    GA     USA  33.755000   -84.401000
# 2         7         M&T Bank Stadium    MD     USA  39.277985   -76.622788
# 3         1            New Era Field    NY     USA  42.773758   -78.786837
# 4        26  Bank of America Stadium    NC     USA  35.225808   -80.852861
#
#   capacity Average attendance      Metro
# 0    63400              62014    Phoenix
# 1    71000              72898    Atlanta
# 2    71008              70431  Baltimore
# 3    73079              64962    Buffalo
# 4    73778              73773  Charlotte

# %%
x = pd.merge(out_df,
                            team_df, 
                            on='stadiumID',how = "left")
x =x[x['key'].isna()]
stadium_no_team = x.iloc[:,:7]

# %%
stadium_no_team.head()
# Out:
#    stadiumID           stadium_name state country   latitude    longitude  \
# 14        14       Qualcomm Stadium    CA     USA  32.783188  -117.119439
# 23        23  Mall of America Field    MN      US  44.976000   -93.225000
# 25        25           Georgia Dome    GA     USA  33.757614   -84.400972
# 28        28       Candlestick Park    CA      US  37.404108  -121.970274
# 30        30      Edward Jones Dome    MO     USA  38.632975   -90.188547
#
#    capacity
# 14    70561
# 23    64111
# 25    74228
# 28    70207
# 30    66000

# %%
us_cities = pd.read_csv('us_cities.txt')
top_cities = us_cities[:300]

# %%
city_team = pd.merge(teams_attendance,
                 top_cities,
                 left_on='Metro', right_on='city')
city_team=city_team.drop('Metro', axis =1 )

# %%
city_team = city_team.drop_duplicates('full_name', keep='first')
city_team
# Out:
#     key  ID         Team_x       Name conference division  \
# 0   ARI   1        Arizona  Cardinals        NFC     West
# 1   ATL   2        Atlanta    Falcons        NFC    South
# 2   BAL   3      Baltimore     Ravens        AFC    North
# 3   BUF   4        Buffalo      Bills        AFC     East
# 4   CAR   5       Carolina   Panthers        NFC    South
# 5   CHI   6        Chicago      Bears        NFC    North
# 6   CIN   7     Cincinnati    Bengals        AFC    North
# 7   CLE   8      Cleveland     Browns        AFC    North
# 8   DAL   9         Dallas    Cowboys        NFC     East
# 9   DEN  10         Denver    Broncos        AFC     West
# 10  DET  11        Detroit      Lions        NFC    North
# 11   GB  12      Green Bay    Packers        NFC    North
# 12  HOU  13        Houston     Texans        AFC    South
# 13  IND  14   Indianapolis      Colts        AFC    South
# 14  JAX  15   Jacksonville    Jaguars        AFC    South
# 15   KC  16    Kansas City     Chiefs        AFC     West
# 17  LAC  29    Los Angeles   Chargers        AFC     West
# 18  LAR  32    Los Angeles       Rams        NFC     West
# 19  MIA  19          Miami   Dolphins        AFC     East
# 20  MIN  20      Minnesota    Vikings        NFC    North
# 21   NE  21    New England   Patriots        AFC     East
# 22   NO  22    New Orleans     Saints        NFC    South
# 23  NYG  23       New York     Giants        NFC     East
# 24  NYJ  24       New York       Jets        AFC     East
# 25  OAK  25        Oakland    Raiders        AFC     West
# 26  PHI  26   Philadelphia     Eagles        NFC     East
# 27  PIT  28     Pittsburgh   Steelers        AFC    North
# 28  SEA  30        Seattle   Seahawks        NFC     West
# 29   SF  31  San Francisco      49ers        NFC     West
# 30  TEN  34      Tennessee     Titans        AFC    South
# 31  WAS  35     Washington   Redskins        NFC     East
#
#                full_name stadiumID                   stadium_name state_x  \
# 0      Arizona Cardinals        29           U of Phoenix Stadium      AZ
# 1        Atlanta Falcons        45          Mercedes-Benz Stadium      GA
# 2       Baltimore Ravens         7               M&T Bank Stadium      MD
# 3          Buffalo Bills         1                  New Era Field      NY
# 4      Carolina Panthers        26        Bank of America Stadium      NC
# 5          Chicago Bears        20                  Soldier Field      IL
# 6     Cincinnati Bengals         5             Paul Brown Stadium      OH
# 7       Cleveland Browns         6            FirstEnergy Stadium      OH
# 8         Dallas Cowboys        17                   AT&T Stadium      TX
# 9         Denver Broncos        13   Broncos Stadium at Mile High      CO
# 10         Detroit Lions        21                     Ford Field      MI
# 11     Green Bay Packers        22                  Lambeau Field      WI
# 12        Houston Texans        11                    NRG Stadium      TX
# 13    Indianapolis Colts         9              Lucas Oil Stadium      IN
# 14  Jacksonville Jaguars        10                TIAA Bank Field      FL
# 15    Kansas City Chiefs        15              Arrowhead Stadium      MO
# 17  Los Angeles Chargers        43                 StubHub Center      CA
# 18      Los Angeles Rams        38  Los Angeles Memorial Coliseum      CA
# 19        Miami Dolphins         2              Hard Rock Stadium      FL
# 20     Minnesota Vikings        42              U.S. Bank Stadium      MN
# 21  New England Patriots         4               Gillette Stadium      MA
# 22    New Orleans Saints        27        Mercedes-Benz Superdome      LA
# 23       New York Giants         3                MetLife Stadium      NJ
# 24         New York Jets         3                MetLife Stadium      NJ
# 25       Oakland Raiders        16               Oakland Coliseum      CA
# 26   Philadelphia Eagles        18        Lincoln Financial Field      PA
# 27   Pittsburgh Steelers         8                    Heinz Field      PA
# 28      Seattle Seahawks        31              CenturyLink Field      WA
# 29   San Francisco 49ers        37                 Levi's Stadium      CA
# 30      Tennessee Titans        12                 Nissan Stadium      TN
# 31   Washington Redskins        19                    FedEx Field      MD
#
#    country   latitude    longitude capacity Average attendance rank  \
# 0      USA  33.527558  -112.263036    63400              62014    6
# 1      USA  33.755000   -84.401000    71000              72898   40
# 2      USA  39.277985   -76.622788    71008              70431   26
# 3      USA  42.773758   -78.786837    73079              64962   73
# 4      USA  35.225808   -80.852861    73778              73773   16
# 5      USA  41.862320   -87.616699    61500              61344    3
# 6      USA  39.095309   -84.516003    65535              50754   65
# 7      USA  41.505885   -81.699458    71516              65765   48
# 8      USA  32.747778   -97.092778    80000              91620    9
# 9      USA  39.743936  -105.020097    76125              76446   22
# 10     USA  42.340021   -83.045777    65000              62758   18
# 11     USA  44.501389   -88.061944    80750              77835  272
# 12     USA  29.684722   -95.410707    71054              71805    4
# 13     USA  39.760056   -86.163806    67000              59200   12
# 14     USA  30.323813   -81.637199    67246              69074   13
# 15     USA  39.049002   -94.483864    76416              75973   37
# 17     USA  33.858663  -118.256666    27000              32768    2
# 18     USA  34.014167  -118.287778    93607              72430    2
# 19     USA  25.957740   -80.238781    76100              65560   44
# 20     USA  44.974288   -93.329728    66655              66811   46
# 21     USA  42.090866   -71.264244    68756              65878   24
# 22     USA  29.950931   -90.081364    73208              73051   51
# 23     USA  40.813611   -74.074444    82500              76941    1
# 24     USA  40.813611   -74.074444    82500              77982    1
# 25     USA  37.751613  -122.200509    53200              57919   45
# 26     USA  39.900771   -75.167469    68532              69696    5
# 27     USA  40.446751   -80.015707    65050              63456   62
# 28     USA  47.595153  -122.331625    67000              69001   21
# 29     USA  37.404108  -121.970274    68500              69149   14
# 30     USA  36.166441   -86.771253    69140              64520   25
# 31     USA  38.907652   -76.864479    85000              61028   23
#
#                   city               state_y population 2000-2013 growth
# 0              Phoenix               Arizona    1513367            14.0%
# 1              Atlanta               Georgia     447841             6.2%
# 2            Baltimore              Maryland     622104            -4.0%
# 3              Buffalo              New York     258959           -11.3%
# 4            Charlotte        North Carolina     792862            39.1%
# 5              Chicago              Illinois    2718782            -6.1%
# 6           Cincinnati                  Ohio     297517           -10.1%
# 7            Cleveland                  Ohio     390113           -18.1%
# 8               Dallas                 Texas    1257676             5.6%
# 9               Denver              Colorado     649495            16.7%
# 10             Detroit              Michigan     688701           -27.1%
# 11           Green Bay             Wisconsin     104779             1.9%
# 12             Houston                 Texas    2195914            11.0%
# 13        Indianapolis               Indiana     843393             7.8%
# 14        Jacksonville               Florida     842583            14.3%
# 15         Kansas City              Missouri     467007             5.5%
# 17         Los Angeles            California    3884307             4.8%
# 18         Los Angeles            California    3884307             4.8%
# 19               Miami               Florida     417650            14.9%
# 20         Minneapolis             Minnesota     400070             4.5%
# 21              Boston         Massachusetts     645966             9.4%
# 22         New Orleans             Louisiana     378715           -21.6%
# 23            New York              New York    8405837             4.8%
# 24            New York              New York    8405837             4.8%
# 25             Oakland            California     406253             1.3%
# 26        Philadelphia          Pennsylvania    1553165             2.6%
# 27          Pittsburgh          Pennsylvania     305841            -8.3%
# 28             Seattle            Washington     652405            15.6%
# 29       San Francisco            California     837442             7.7%
# 30  Nashville-Davidson             Tennessee     634464            16.2%
# 31          Washington  District of Columbia     646449            13.0%

# %%
top_50_cities = us_cities[:50]
city_with_team = city_team['city'].tolist()
top_50_cities_city = top_50_cities['city'].tolist()
top_50_cities_no =top_50_cities_city[top_50_cities_city not in city_with_team]

# %%
top_50_cities_no = []
for city in top_50_cities_city:
    if city in city_with_team:
        continue
    else: 
        top_50_cities_no.append(city)

# %%
top_50_series_no = pd.Series(top_50_cities_no)
top_50_series_no = pd.DataFrame(top_50_series_no).reset_index()
top_50_series_no.columns = ['index','city']
top_50_series_no=top_50_series_no.drop('index', axis =1 )
city_50_no_team = pd.merge(top_50_cities, top_50_series_no,
                          on = 'city')
city_50_no_team = city_50_no_team.drop([2,5,17,18,25]) #Manually removing cities part of metro with teams
city_50_no_team
# Out:
#    rank                         city           state population  \
# 0     7                  San Antonio           Texas    1409019
# 1     8                    San Diego      California    1355896
# 3    11                       Austin           Texas     885400
# 4    15                     Columbus            Ohio     822553
# 6    19                      El Paso           Texas     674433
# 7    20                      Memphis       Tennessee     653450
# 8    27                Oklahoma City        Oklahoma     610613
# 9    28  Louisville/Jefferson County        Kentucky     609893
# 10   29                     Portland          Oregon     609456
# 11   30                    Las Vegas          Nevada     603488
# 12   31                    Milwaukee       Wisconsin     599164
# 13   32                  Albuquerque      New Mexico     556495
# 14   33                       Tucson         Arizona     526116
# 15   34                       Fresno      California     509924
# 16   35                   Sacramento      California     479686
# 19   39               Virginia Beach        Virginia     448479
# 20   41             Colorado Springs        Colorado     439886
# 21   42                        Omaha        Nebraska     434353
# 22   43                      Raleigh  North Carolina     431746
# 23   47                        Tulsa        Oklahoma     398121
# 24   49                      Wichita          Kansas     386552
#
#    2000-2013 growth
# 0             21.0%
# 1             10.5%
# 3             31.7%
# 4             14.8%
# 6             19.4%
# 7             -5.3%
# 8             20.2%
# 9             10.0%
# 10            15.0%
# 11            24.5%
# 12             0.3%
# 13            23.5%
# 14             7.5%
# 15            18.3%
# 16            17.2%
# 19             5.1%
# 20            21.4%
# 21             5.9%
# 22            48.7%
# 23             1.3%
# 24             9.7%

# %%
city_team.to_csv('teams_with_stadium.csv')
stadium_no_team.to_csv('stadiums_without_a_team.csv')
city_50_no_team.to_csv('big_cities_without_a_team.csv')
